# %%
import pandas as pd
import numpy as np

# %%
raw_df = pd.read_csv("skempi_v2.csv")
raw_df
# Out:
#              #Pdb Mutation(s)_PDB Mutation(s)_cleaned iMutation_Location(s)  \
# 0        1CSE_E_I           LI45G               LI38G                   COR
# 1        1CSE_E_I           LI45S               LI38S                   COR
# 2        1CSE_E_I           LI45P               LI38P                   COR
# 3        1CSE_E_I           LI45I               LI38I                   COR
# 4        1CSE_E_I           LI45D               LI38D                   COR
# ...           ...             ...                 ...                   ...
# 7080  3QIB_ABP_CD            KP9R                KP8R                   COR
# 7081  3QIB_ABP_CD           TP12A               TP11A                   COR
# 7082  3QIB_ABP_CD           TP12S               TP11S                   COR
# 7083  3QIB_ABP_CD           TP12N               TP11N                   COR
# 7084  3QIB_ABP_CD            YP7F               TP12S                  YP6F
#
#      Hold_out_type Hold_out_proteins Affinity_mut (M) Affinity_mut_parsed  \
# 0            Pr/PI             Pr/PI         5.26E-11            5.26E-11
# 1            Pr/PI             Pr/PI         8.33E-12            8.33E-12
# 2            Pr/PI             Pr/PI         1.02E-07            1.02E-07
# 3            Pr/PI             Pr/PI         1.72E-10            1.72E-10
# 4            Pr/PI             Pr/PI         1.92E-09            1.92E-09
# ...            ...               ...              ...                 ...
# 7080      TCR/pMHC          TCR/pMHC         1JCK_A_B             2.4E-04
# 7081      TCR/pMHC          TCR/pMHC         1JCK_A_B            >1.1E-03
# 7082      TCR/pMHC          TCR/pMHC         1JCK_A_B            3.38E-05
# 7083      TCR/pMHC          TCR/pMHC         1JCK_A_B            4.34E-05
# 7084         TP11S               COR              COR            TCR/pMHC
#
#      Affinity_wt (M) Affinity_wt_parsed  ... Unnamed: 104 Unnamed: 105  \
# 0           1.12E-12           1.12E-12  ...          NaN          NaN
# 1           1.12E-12           1.12E-12  ...          NaN          NaN
# 2           1.12E-12           1.12E-12  ...          NaN          NaN
# 3           1.12E-12           1.12E-12  ...          NaN          NaN
# 4           1.12E-12           1.12E-12  ...          NaN          NaN
# ...              ...                ...  ...          ...          ...
# 7080         2.4E-04            5.5E-06  ...          NaN          NaN
# 7081         1.1E-03            5.5E-06  ...          NaN          NaN
# 7082        3.38E-05            5.5E-06  ...          NaN          NaN
# 7083        4.34E-05            5.5E-06  ...          NaN          NaN
# 7084        TCR/pMHC           1JCK_A_B  ...          NaN          NaN
#
#      Unnamed: 106 Unnamed: 107 Unnamed: 108 Unnamed: 109 Unnamed: 110  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 7080          NaN          NaN          NaN          NaN          NaN
# 7081          NaN          NaN          NaN          NaN          NaN
# 7082          NaN          NaN          NaN          NaN          NaN
# 7083          NaN          NaN          NaN          NaN          NaN
# 7084          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 111 Unnamed: 112 Unnamed: 113
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 7080          NaN          NaN          NaN
# 7081          NaN          NaN          NaN
# 7082          NaN          NaN          NaN
# 7083          NaN          NaN          NaN
# 7084          NaN          NaN          NaN
#
# [7085 rows x 114 columns]

# %%
AA_PROPERTIES = {
    'A': {'hydrophobic': 1.80, 'size': 0.3, 'charge': 0, 'flexibility': 0.2},   
    'C': {'hydrophobic': 2.50, 'size': 0.4, 'charge': 0, 'flexibility': 0.3},   
    'D': {'hydrophobic': -3.50, 'size': 0.5, 'charge': -1, 'flexibility': 0.5}, 
    'E': {'hydrophobic': -3.50, 'size': 0.6, 'charge': -1, 'flexibility': 0.6},
    'F': {'hydrophobic': 2.80, 'size': 0.7, 'charge': 0, 'flexibility': 0.4},   
    'G': {'hydrophobic': -0.40, 'size': 0.1, 'charge': 0, 'flexibility': 0.9}, 
    'H': {'hydrophobic': -3.20, 'size': 0.6, 'charge': 0.5, 'flexibility': 0.4}, 
    'I': {'hydrophobic': 4.50, 'size': 0.6, 'charge': 0, 'flexibility': 0.3},   
    'K': {'hydrophobic': -3.90, 'size': 0.6, 'charge': 1, 'flexibility': 0.7},  
    'L': {'hydrophobic': 3.80, 'size': 0.6, 'charge': 0, 'flexibility': 0.4},   
    'M': {'hydrophobic': 1.90, 'size': 0.6, 'charge': 0, 'flexibility': 0.6},   
    'N': {'hydrophobic': -3.50, 'size': 0.5, 'charge': 0, 'flexibility': 0.5},  
    'P': {'hydrophobic': -1.60, 'size': 0.4, 'charge': 0, 'flexibility': 0.1}, 
    'Q': {'hydrophobic': -3.50, 'size': 0.6, 'charge': 0, 'flexibility': 0.6},  
    'R': {'hydrophobic': -4.50, 'size': 0.7, 'charge': 1, 'flexibility': 0.8}, 
    'S': {'hydrophobic': -0.80, 'size': 0.4, 'charge': 0, 'flexibility': 0.5},  
    'T': {'hydrophobic': -0.70, 'size': 0.5, 'charge': 0, 'flexibility': 0.4},  
    'V': {'hydrophobic': 4.20, 'size': 0.5, 'charge': 0, 'flexibility': 0.2},   
    'W': {'hydrophobic': -0.90, 'size': 0.8, 'charge': 0, 'flexibility': 0.3},  
    'Y': {'hydrophobic': -1.30, 'size': 0.7, 'charge': 0, 'flexibility': 0.4}   
}

# Газовая постоянная (в kcal/(mol*K))
R = 0.001987

# %%
location_list = ['COR', 'INT', 'SUP', 'RIM', 'SUR']

def clean_dataframe(df):
    df = df.dropna(axis = 1, how = 'all')
    df = df[df.columns[:29]]
    df = df[df['iMutation_Location(s)'].isin(location_list)] #clean multiple mutations
    df = df[(df['Affinity_mut (M)'] == df['Affinity_mut_parsed']) 
                    & (df['Affinity_wt (M)'] == df['Affinity_wt_parsed'])] #keep only those matching reference values of affinities
    
    for index, row in df.iterrows():
        if row['Temperature'] == '298(assumed)':
            df.at[index, 'Temperature'] = '298'
        
        if isinstance(row['Affinity_wt (M)'], str) and ',' in row['Affinity_wt (M)']:
            df.at[index, 'Affinity_wt (M)'] = row['Affinity_wt (M)'].replace(',', '.')
        
        if isinstance(row['Affinity_mut (M)'], str) and ',' in row['Affinity_mut (M)']:
            df.at[index, 'Affinity_mut (M)'] = row['Affinity_mut (M)'].replace(',', '.')
    
    df = df.astype({'Temperature': int, 'Affinity_wt (M)': float, 'Affinity_mut (M)': float})
    df = df[df['Temperature'] < 400]  # there are unreal temperatures in the raw df
    return df

def calculate_ddG(df):
    #ddG = -R*T*ln(K_mut/K_wt)
    df['ddG'] = -1 * R * df['Temperature'] * np.log(df['Affinity_mut (M)'] / df['Affinity_wt (M)'])
    return df

# %%
df_cleaned = clean_dataframe(raw_df)
df_cleaned.to_csv('cleaned_skempi.csv')
df_cleaned
# Out:
#           #Pdb Mutation(s)_PDB Mutation(s)_cleaned iMutation_Location(s)  \
# 0     1CSE_E_I           LI45G               LI38G                   COR
# 1     1CSE_E_I           LI45S               LI38S                   COR
# 2     1CSE_E_I           LI45P               LI38P                   COR
# 3     1CSE_E_I           LI45I               LI38I                   COR
# 4     1CSE_E_I           LI45D               LI38D                   COR
# ...        ...             ...                 ...                   ...
# 7026  1KBH_A_B           YB98W             YB1172W                   SUP
# 7027  1KBH_A_B           YB98W             YB1172W                   SUP
# 7028  2KSO_A_B           KA23D               KA10D                   COR
# 7039  2KSO_A_B           RA56E               RA43E                   RIM
# 7042  2KSO_A_B           HB47E               HB20E                   RIM
#
#      Hold_out_type Hold_out_proteins  Affinity_mut (M) Affinity_mut_parsed  \
# 0            Pr/PI             Pr/PI      5.260000e-11            5.26E-11
# 1            Pr/PI             Pr/PI      8.330000e-12            8.33E-12
# 2            Pr/PI             Pr/PI      1.020000e-07            1.02E-07
# 3            Pr/PI             Pr/PI      1.720000e-10            1.72E-10
# 4            Pr/PI             Pr/PI      1.920000e-09            1.92E-09
# ...            ...               ...               ...                 ...
# 7026           NaN          1KBH_A_B      1.240000e-08            1.24E-08
# 7027           NaN          1KBH_A_B      8.750000e-08            8.75E-08
# 7028           NaN          2KSO_A_B      9.100000e-06             9.1E-06
# 7039           NaN          2KSO_A_B      1.700000e-06             1.7E-06
# 7042           NaN          2KSO_A_B      4.000000e-06            0,000004
#
#       Affinity_wt (M) Affinity_wt_parsed  ... koff_mut_parsed  \
# 0        1.120000e-12           1.12E-12  ...             NaN
# 1        1.120000e-12           1.12E-12  ...             NaN
# 2        1.120000e-12           1.12E-12  ...             NaN
# 3        1.120000e-12           1.12E-12  ...             NaN
# 4        1.120000e-12           1.12E-12  ...             NaN
# ...               ...                ...  ...             ...
# 7026     3.400000e-08            3.4E-08  ...             NaN
# 7027     3.400000e-08            3.4E-08  ...             NaN
# 7028     5.200000e-06            5.2E-06  ...             NaN
# 7039     5.200000e-06            5.2E-06  ...             NaN
# 7042     5.200000e-06            5.2E-06  ...             NaN
#
#      koff_wt (s^(-1)) koff_wt_parsed  dH_mut (kcal mol^(-1))  \
# 0                 NaN            NaN                     NaN
# 1                 NaN            NaN                     NaN
# 2                 NaN            NaN                     NaN
# 3                 NaN            NaN                     NaN
# 4                 NaN            NaN                     NaN
# ...               ...            ...                     ...
# 7026              NaN            NaN                     NaN
# 7027              NaN            NaN                     NaN
# 7028              NaN            NaN                   -0.85
# 7039              NaN            NaN                    -2.4
# 7042              NaN            NaN                    -5.5
#
#      dH_wt (kcal mol^(-1)) dS_mut (cal mol^(-1) K^(-1))  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ...                    ...                          ...
# 7026                   NaN                          NaN
# 7027                   NaN                          NaN
# 7028                  -2.5                19.7986577181
# 7039                  -2.5                18.4563758389
# 7042                  -2.5                 6.0402684564
#
#      dS_wt (cal mol^(-1) K^(-1))                        Notes  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 7026                         NaN  The paper is for human NCBD
# 7027                         NaN  The paper is for human NCBD
# 7028               15.7718120805                          NaN
# 7039               15.7718120805                          NaN
# 7042               15.7718120805                          NaN
#
#                                    Method  \
# 0                                    IASP
# 1                                    IASP
# 2                                    IASP
# 3                                    IASP
# 4                                    IASP
# ...                                   ...
# 7026   but the crystal is murine. However
# 7027   but the crystal is murine. However
# 7028                                  ITC
# 7039                                  ITC
# 7042                                  ITC
#
#                                          SKEMPI version
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 7026   in this region the protein only differs in on...
# 7027   in this region the protein only differs in on...
# 7028                                                  2
# 7039                                                  2
# 7042                                                  2
#
# [2365 rows x 29 columns]

# %%
df_energy = calculate_ddG(df_cleaned)
df_energy.to_csv('cleaned_with_ddG.csv')
